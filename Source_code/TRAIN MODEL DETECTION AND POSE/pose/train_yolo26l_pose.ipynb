# %% [markdown]
# # Train YOLO-pose — YOLO26 Medium Pose
#
# **Dataset:** `KLTN_POSE_V6_CLEAN` (4 keypoint TL→TR→BR→BL, 4 lớp, `kpt_shape [4,3]`, `flip_idx [1,0,3,2]`)
#
# **Cách dùng:** Add Input file `.zip` dataset → Run All. Kết quả tải về ở `training_results_yolo26m.zip`.
#
# | | |
# |---|---|
# | model | `yolo26m-pose.pt` |
# | epochs / patience | 200 / 50 |
# | batch / imgsz | 16 / 640 |
# | dropout / weight_decay | 0.25 / 0.0005 |
#
# > `imgsz=640` phải giữ nguyên khi suy diễn — chạy lệch scale làm tụt độ chính xác.

# %%
# 1. CÀI ĐẶT MÔI TRƯỜNG VÀ TẮT LOGGING CHỐNG KẸT
# !pip install -q ultralytics
import os, gc, glob, shutil, re, collections
from ultralytics import YOLO

os.environ['WANDB_DISABLED'] = 'true'
os.environ['WANDB_MODE'] = 'dryrun'
os.environ['CLEARML_WEB_HOST'] = ''
print('[OK] Moi truong san sang')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 725.8 kB/s eta 0:00:00 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.7 MB/s eta 0:00:0000:0100:01
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# [OK] Moi truong san sang

# %%
# 2. TÌM DATASET + FIX ĐƯỜNG DẪN KAGGLE
yaml_paths = glob.glob('/kaggle/input/**/dataset.yaml', recursive=True)

if not yaml_paths:
    raise FileNotFoundError(
        'Khong tim thay dataset.yaml. Hay Add Input file .zip dataset vao notebook truoc!')

dataset_yaml = yaml_paths[0]
dataset_dir  = os.path.dirname(dataset_yaml)
print(f'[OK] Tim thay dataset tai: {dataset_yaml}')

with open(dataset_yaml, 'r', encoding='utf-8') as f:
    yaml_content = f.read()

# Ep path: ve dung thu muc thuc te tren Kaggle (path trong zip la duong dan may local)
new_yaml = re.sub(r'path:.*', f'path: {dataset_dir}', yaml_content)
working_yaml = '/kaggle/working/dataset.yaml'
with open(working_yaml, 'w', encoding='utf-8') as f:
    f.write(new_yaml)

print(f'[OK] Da fix path -> {working_yaml}\n')
print(new_yaml)
# Out:
# [OK] Tim thay dataset tai: /kaggle/input/datasets/tungtungtungtung/data-pose-final/dataset.yaml
# [OK] Da fix path -> /kaggle/working/dataset.yaml
#
# # KLTN Pose V6 - CLEAN (split TRUOC, augment CHI train -> khong data leak)
# path: /kaggle/input/datasets/tungtungtungtung/data-pose-final
# train: train/images
# val: val/images
# test: test/images
#
# kpt_shape: [4, 3]
# flip_idx: [1, 0, 3, 2]
#
# names:
#   0: anten-4G
#   1: anten-5G
#   2: rrh
#   3: rru
# nc: 4

# %%
# 3. KIỂM TRA DATASET TRƯỚC KHI TRAIN (chan loi "0 nhan" / sai format)
# Pose 4 diem: moi dong label phai co 1(class) + 4(box) + 4*3(kp) = 17 truong.
NUM_KP, EXP = 4, 1 + 4 + 4 * 3

assert 'kpt_shape' in new_yaml, 'THIEU kpt_shape trong dataset.yaml -> khong train pose duoc'
assert 'flip_idx'  in new_yaml, 'THIEU flip_idx -> fliplr se lam LOAN thu tu keypoint'

tong_obj = 0
for sp in ('train', 'val', 'test'):
    img_dir = os.path.join(dataset_dir, sp, 'images')
    lbl_dir = os.path.join(dataset_dir, sp, 'labels')
    if not os.path.isdir(img_dir):
        print(f'[--] khong co split "{sp}"'); continue
    imgs = [f for f in os.listdir(img_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    lbls = glob.glob(os.path.join(lbl_dir, '*.txt'))
    cd, bad, obj, suybien = collections.Counter(), 0, 0, 0
    for lf in lbls:
        for ln in open(lf):
            p = ln.split()
            if not p:
                continue
            if len(p) != EXP:
                bad += 1; continue
            cd[int(p[0])] += 1; obj += 1
            # 4 keypoint trung nhau -> tu giac suy bien, solvePnP vo nghia
            pts = {(round(float(p[5 + k*3]), 5), round(float(p[6 + k*3]), 5)) for k in range(NUM_KP)}
            if len(pts) < NUM_KP:
                suybien += 1
    tong_obj += obj
    print(f'[{sp:5}] {len(imgs):4} anh | {len(lbls):4} label | {obj:5} object | '
          f'sai format: {bad} | keypoint trung nhau: {suybien} | theo lop: {dict(sorted(cd.items()))}')

assert tong_obj > 0, 'DATASET RONG -> kiem tra lai buoc split/convert'
print('\n[OK] Dataset hop le, bat dau train duoc.')
# Out:
# [train]  676 anh |  676 label |  1768 object | sai format: 0 | keypoint trung nhau: 0 | theo lop: {0: 1204, 1: 168, 2: 132, 3: 264}
# [val  ]   21 anh |   21 label |    69 object | sai format: 0 | keypoint trung nhau: 0 | theo lop: {0: 48, 1: 7, 2: 2, 3: 12}
# [test ]   21 anh |   21 label |    56 object | sai format: 0 | keypoint trung nhau: 0 | theo lop: {0: 43, 1: 6, 2: 1, 3: 6}
#
# [OK] Dataset hop le, bat dau train duoc.

# %%
# 4. HUẤN LUYỆN YOLO26 Medium Pose
model_variant = 'yolo26m-pose.pt'

epochs       = 200
patience     = 50          # dung som neu 50 epoch khong cai thien
batch_size   = 16
img_size     = 640         # PHAI trung voi imgsz luc suy dien
dropout      = 0.25
weight_decay = 0.0005

# Bat Dual-GPU neu Kaggle dang cap 2x T4
device = '0,1' if os.path.exists('/dev/nvidia1') else '0'
print(f'model={model_variant} | device={device} | batch={batch_size} | imgsz={img_size}')

model = YOLO(model_variant)
results = model.train(
    data=working_yaml,
    epochs=epochs,
    patience=patience,
    batch=batch_size,
    imgsz=img_size,
    device=device,
    dropout=dropout,
    weight_decay=weight_decay,
    project='/kaggle/working/runs',
    name='pose_model',      # giu ten nay de khop script chay local
    exist_ok=True,
    plots=True,
)
print('[OK] Train xong.')
# Out:
# model=yolo26m-pose.pt | device=0,1 | batch=16 | imgsz=640
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26m-pose.pt to 'yolo26m-pose.pt': 100% ━━━━━━━━━━━━ 46.8MB 44.7MB/s 1.0s1.0s<0.1s9s
# Ultralytics 8.4.107 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
#                                                         CUDA:1 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset.yaml, degrees=0.0, deterministic=True, device=0,1, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.25, dynamic=False, embed=None, end2end=None, epochs=200, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26m-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=pose_model, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=50, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/pose_model, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 5.0MB/s 0.1s 0.1s<0.2s
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[4, 3]
# Overriding model.yaml nc=1 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   4563648  ultralytics.nn.modules.head.Pose26           [4, [4, 3], 1, True, [256, 512, 512]]
# YOLO26m-pose summary: 383 layers, 23,537,920 parameters, 23,537,920 gradients, 82.2 GFLOPs
#
# Transferred 843/939 items from pretrained weights
# DDP: debug command /usr/bin/python3 -m torch.distributed.run --nproc_per_node 2 --master_port 18599 /root/.config/Ultralytics/DDP/_temp_a8noan8j136087126337984.py
# Ultralytics 8.4.107 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
#                                                         CUDA:1 (Tesla T4, 14912MiB)
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[4, 3]
# Overriding model.yaml nc=1 with nc=4
# Transferred 843/939 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 5.3MB/s 1.0s.9s<0.1s1.2s
# AMP: checks passed ✅
# WARNING ⚠️ train: Slow image access detected (ping: 0.0±0.0 ms, read: 20.2±8.8 MB/s, size: 60.9 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# train: Scanning /kaggle/input/datasets/tungtungtungtung/data-pose-final/train/labels... 676 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 676/676 402.1it/s 1.7s0.0s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/tungtungtungtung/data-pose-final/train is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# WARNING ⚠️ val: Slow image access detected (ping: 0.5±0.2 ms, read: 31.6±35.0 MB/s, size: 196.3 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/input/datasets/tungtungtungtung/data-pose-final/val/labels... 21 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 21/21 392.8it/s 0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/tungtungtungtung/data-pose-final/val is not writable, cache not saved.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 136 weight(decay=0.0), 196 weight(decay=0.0005), 196 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/pose_model/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/pose_model
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       1/200      4.89G      2.204      4.722     0.6996      7.311    0.00707      13.63         13        640: 100% ━━━━━━━━━━━━ 43/43 1.1it/s 38.4s0.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.0s/it 3.0s
#                    all         21         69      0.905      0.128       0.16     0.0897      0.769     0.0104    0.00292   0.000293
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       2/200      6.08G      1.556       2.04     0.4496      2.704   0.003758       5.51          4        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.6s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.185      0.531      0.325      0.182       0.17       0.49      0.308      0.173
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       3/200      6.11G      1.586      1.595     0.3285      2.058     0.0044       5.04          4        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.4s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.483      0.439      0.464      0.279      0.481      0.439      0.443      0.284
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       4/200      6.11G       1.53      1.218     0.2844      1.653   0.004136      4.112          6        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69       0.63      0.401      0.436      0.273      0.308      0.548      0.443      0.353
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       5/200      6.11G      1.467     0.9849     0.2776      1.447   0.004336      3.648         11        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.478      0.355      0.485      0.318      0.473       0.35      0.415      0.357
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       6/200      6.11G      1.491     0.9996     0.2978      1.396   0.004284      3.477          6        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 23.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.721      0.481      0.539      0.333      0.721      0.481      0.515      0.418
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       7/200      6.12G      1.444      0.887     0.2945      1.316   0.004022      3.378         14        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.434       0.61      0.565      0.379      0.425      0.511      0.504      0.454
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       8/200      6.12G      1.378     0.8769     0.2776      1.253   0.004193      3.323          4        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.704      0.498       0.52      0.347      0.704      0.498      0.511      0.457
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       9/200      6.12G      1.343     0.7746     0.2492      1.194   0.003339      2.477          7        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.4s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.535      0.758      0.589      0.363      0.499      0.612      0.503      0.451
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      10/200      6.12G      1.326     0.7923     0.2534      1.164   0.003581      2.726          9        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69       0.61      0.597      0.613       0.43       0.61      0.597      0.592       0.53
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      11/200      6.12G       1.27      0.718     0.2723        1.1   0.003493      2.441          8        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.2s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.619      0.685      0.685      0.493      0.622      0.571      0.654      0.588
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      12/200      6.12G      1.222      0.632     0.2516      1.095   0.003772      2.405          1        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.555      0.586      0.577      0.376      0.555      0.586      0.557      0.488
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      13/200      6.12G      1.258     0.6626     0.2485      1.056   0.003873      2.361          8        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.558      0.599      0.627      0.472      0.709      0.471      0.608      0.585
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      14/200      6.12G      1.204     0.6748     0.2628      1.046   0.003624      2.028          8        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.457      0.748      0.661      0.425      0.434      0.713      0.634      0.563
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      15/200      6.12G      1.197      0.515     0.2239     0.9571   0.003173       1.54         17        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.439      0.744      0.563      0.399      0.663      0.473      0.568       0.47
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      16/200      6.12G      1.214     0.5674     0.2518     0.9262   0.003219      1.359         13        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.643      0.778      0.646      0.433      0.583      0.743        0.6      0.491
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      17/200      6.12G      1.133     0.5534     0.2732     0.9404    0.00309      1.754         11        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.676      0.632      0.735      0.526      0.676      0.632      0.735      0.661
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      18/200      6.12G      1.135     0.4875     0.2134     0.8514   0.002836      1.164         18        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.3s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.839      0.497      0.619      0.433      0.801      0.454      0.571      0.521
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      19/200      6.12G      1.127     0.4568      0.234     0.8325   0.003078      1.182          9        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.532      0.578      0.616       0.44      0.532      0.578      0.603      0.549
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      20/200      6.12G       1.07     0.4475     0.2363     0.8168   0.002632     0.7978         13        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.751      0.674      0.808      0.609      0.751      0.674      0.799       0.75
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      21/200      6.12G      1.142     0.4682     0.2408     0.8827   0.003072     0.9978          7        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.762      0.575      0.736      0.501      0.762      0.575      0.687      0.631
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      22/200      6.12G      1.081     0.3973     0.2337     0.7826   0.003113      1.064         12        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.769      0.665      0.763      0.547      0.722      0.632       0.68      0.629
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      23/200      6.12G        1.1     0.4037     0.2339     0.7943   0.003601      1.121          5        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69       0.75      0.699      0.767      0.589      0.698      0.664      0.703      0.666
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      24/200      6.12G      1.078     0.3967     0.2441     0.7492   0.003044      1.084          6        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.667      0.664      0.669      0.504      0.667      0.664      0.659      0.614
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      25/200      6.12G      1.051     0.4205     0.2086     0.7076   0.002633      0.492         23        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.799      0.688      0.756      0.558      0.799      0.688      0.731      0.691
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      26/200      6.12G      1.056      0.386       0.23      0.691   0.002865     0.8192          7        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.6s
#                    all         21         69      0.829      0.649       0.81      0.596      0.814      0.617      0.755      0.662
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      27/200      6.12G     0.9882     0.3398     0.2351      0.687   0.002403     0.3582          8        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.755      0.614      0.776       0.58      0.755      0.614      0.768      0.719
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      28/200      6.12G      1.052     0.3145     0.2257     0.7188   0.002776     0.4879          5        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69       0.72      0.563      0.706      0.548       0.72      0.563      0.698      0.668
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      29/200      6.12G      1.081     0.4335     0.2091     0.7576   0.003213     0.8814         11        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.852      0.642      0.734      0.532      0.852      0.642      0.705      0.676
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      30/200      6.12G     0.9921     0.3487     0.2008     0.6663   0.002712     0.4276          5        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.6s
#                    all         21         69      0.863      0.635      0.755      0.559      0.863      0.635      0.705      0.638
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      31/200      6.12G      1.032      0.344     0.2054     0.7117   0.003054     0.5518          3        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.726        0.7      0.751       0.53      0.726        0.7      0.751      0.684
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      32/200      6.12G      1.106     0.4303     0.2026     0.7418    0.00299     0.6377          4        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.785      0.682      0.745      0.556      0.785      0.682      0.707      0.665
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      33/200      6.12G      1.065     0.3979     0.2274     0.6933   0.002942     0.7085          4        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.857      0.635      0.736      0.538      0.857      0.635      0.736      0.694
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      34/200      6.12G       1.07     0.3846     0.2278     0.6819   0.002573     0.4263         10        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.708      0.602      0.754      0.591      0.708      0.602      0.748      0.702
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      35/200      6.12G       1.05     0.3981     0.2225     0.6641   0.002994     0.6614          6        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.679      0.704      0.671      0.497      0.674      0.699      0.665      0.582
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      36/200      6.12G      1.092     0.4049     0.2035     0.6835   0.002968     0.6583          3        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.759      0.816      0.821       0.59      0.739      0.782      0.793      0.756
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      37/200      6.12G      1.016     0.3287     0.2263     0.6334   0.002894     0.4781         10        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.781      0.834      0.861      0.643      0.781      0.834      0.861      0.818
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      38/200      6.12G      1.099       0.37     0.2134     0.6976   0.002942      0.595          5        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.887      0.613      0.747      0.573      0.887      0.613      0.725      0.668
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      39/200      6.12G      1.057     0.3786     0.1806       0.67   0.002507     0.3217          6        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.821      0.668      0.775      0.582      0.784      0.632      0.685      0.665
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      40/200      6.12G      1.005     0.3728     0.1731     0.6638   0.002488     0.4665          8        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.7s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.901      0.626      0.735      0.584      0.795      0.622      0.689      0.654
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      41/200      6.12G     0.9915     0.3228     0.1946     0.6122   0.002543     0.5466          7        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69       0.84      0.723      0.808      0.619       0.84      0.723      0.795       0.77
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      42/200      6.12G      1.002     0.3719     0.1982     0.6707   0.002689     0.5952          7        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.6s
#                    all         21         69      0.638      0.648      0.708      0.551      0.638      0.648      0.714      0.688
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      43/200      6.12G      1.046     0.3436     0.2114     0.7287   0.002762     0.4829          4        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.902      0.674      0.795      0.609      0.902      0.674      0.795      0.772
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      44/200      6.12G     0.9319     0.2929     0.1917     0.6061   0.002577     0.3198          3        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.789      0.612      0.756      0.558      0.789      0.612      0.762      0.748
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      45/200      6.12G      0.942     0.2943     0.1742     0.5691   0.002412     0.2818          5        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.744      0.738      0.809      0.635      0.744      0.738      0.809      0.779
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      46/200      6.12G     0.9626     0.3264     0.1708     0.6229   0.002989     0.5418          7        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.853      0.592      0.787      0.595      0.853      0.592      0.782      0.754
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      47/200      6.12G      1.021     0.3049      0.163     0.5718   0.002665     0.4602         18        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.704      0.703      0.777      0.597      0.704      0.703       0.77      0.739
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      48/200      6.12G     0.9616     0.2712      0.177     0.5783   0.002568     0.2351          6        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.736      0.677      0.729      0.567      0.736      0.677      0.729      0.693
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      49/200      6.12G     0.9651     0.2458     0.1587     0.5531    0.00246     0.1552         12        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.6s
#                    all         21         69      0.912      0.702      0.826      0.626      0.912      0.702      0.819      0.774
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      50/200      6.12G      0.957     0.3031     0.1499     0.5514   0.002517     0.3393          3        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.737      0.657      0.768      0.616      0.737      0.657      0.759       0.73
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      51/200      6.12G     0.9655     0.2725     0.1409     0.5425   0.002539      0.241          7        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69       0.75      0.699      0.786      0.622       0.75      0.699      0.757      0.737
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      52/200      6.12G     0.9298     0.2909     0.1643     0.5548   0.002577     0.3051          6        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.645       0.66      0.747      0.583      0.645       0.66      0.747      0.729
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      53/200      6.12G     0.9636     0.3118      0.127     0.5396   0.002294     0.2032          7        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69       0.66       0.85      0.716       0.52       0.66       0.85      0.713      0.653
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      54/200      6.12G      0.923     0.2592     0.1407     0.5486   0.002373     0.3352          6        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.6s
#                    all         21         69      0.657      0.738      0.677      0.519      0.657      0.738      0.646      0.611
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      55/200      6.12G      1.054     0.3805     0.1508     0.6102   0.002744     0.6118          8        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.727      0.631      0.701      0.524      0.727      0.631      0.701      0.685
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      56/200      6.12G      0.957     0.2856     0.1441     0.5122   0.002401       0.29          9        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.7s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69       0.89      0.612      0.753      0.589       0.89      0.612      0.753       0.74
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      57/200      6.12G     0.9461     0.2731     0.1363     0.5091   0.002348       0.09          5        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all         21         69      0.877      0.685      0.772      0.569      0.877      0.685      0.772      0.758
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      58/200      6.12G      0.902     0.2605     0.1438     0.5303   0.002552     0.2969         13        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.677      0.742      0.709      0.547      0.677      0.742      0.709      0.691
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      59/200      6.12G     0.9166     0.2831     0.1274     0.5252   0.002279      0.112          6        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.853      0.618      0.781      0.598      0.853      0.618      0.781      0.764
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      60/200      6.12G      1.018     0.2909     0.1263     0.5342   0.002762     0.3522         19        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.789      0.613      0.813       0.58      0.789      0.613      0.772      0.702
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      61/200      6.12G     0.9746     0.3277     0.1474     0.5437   0.002459     0.4443          8        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.729      0.633      0.667      0.515      0.729      0.633      0.636      0.605
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      62/200      6.12G     0.9811     0.3605     0.1187     0.5716   0.002228     0.1794          8        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.745       0.65      0.771       0.56      0.745       0.65      0.722       0.66
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      63/200      6.12G     0.9918     0.2827     0.1242     0.5717   0.002637     0.3493          9        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.683      0.821      0.746      0.575      0.648      0.666      0.643      0.625
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      64/200      6.12G     0.9451     0.2512     0.1216     0.5789   0.002679     0.5228          3        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.754      0.643      0.688      0.525      0.754      0.643      0.684      0.645
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      65/200      6.12G      1.098     0.3469     0.1188     0.6389   0.002672     0.2614          4        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.683      0.648       0.77      0.624      0.683      0.648       0.73      0.719
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      66/200      6.12G     0.9783     0.2879     0.1371      0.589   0.002518      0.332          6        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.791      0.706      0.746      0.588      0.791      0.706      0.719      0.704
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      67/200      6.12G     0.8709     0.2957     0.1237     0.5146   0.002512     0.4135          6        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.687      0.661      0.749       0.59      0.687      0.661      0.734      0.713
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      68/200      6.12G     0.8921     0.3165      0.124      0.518   0.002535     0.3501          4        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.6s
#                    all         21         69      0.794      0.652      0.767      0.624      0.794      0.652      0.726      0.708
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      69/200      6.12G     0.9353     0.3288     0.1034     0.4985   0.002298     0.1497         12        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.877      0.628      0.742      0.585      0.877      0.628      0.731       0.72
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      70/200      6.12G     0.9584     0.2719     0.1129     0.4875   0.002619     0.3165         20        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.766      0.655      0.714      0.555      0.766      0.655      0.706       0.69
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      71/200      6.12G     0.9493     0.2273     0.1106      0.523   0.002574     0.2932          7        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.849      0.694      0.721       0.58      0.849      0.694      0.721      0.695
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      72/200      6.12G     0.9033     0.2747     0.1063     0.5018   0.002287     0.1977          2        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.848      0.707      0.791      0.621      0.848      0.707      0.783      0.768
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      73/200      6.12G     0.8863     0.2474    0.09777     0.4869   0.002265     0.2694          6        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         21         69      0.829      0.668      0.773      0.613      0.829      0.668      0.773      0.754
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      74/200      6.12G     0.8788     0.2586     0.1134     0.5179   0.002359     0.3442          1        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.837      0.683      0.752      0.572      0.902      0.634       0.72      0.704
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      75/200      6.12G     0.8825     0.2728     0.1014     0.4812   0.002382     0.3288          5        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69       0.81      0.586      0.713      0.547       0.81      0.586      0.713      0.694
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      76/200      6.12G     0.8815     0.2187    0.09467     0.4432   0.002152     0.1435          7        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.907      0.689       0.75        0.6      0.907      0.689      0.741      0.722
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      77/200      6.12G     0.8373      0.243    0.09637     0.4155     0.0022    0.05194         10        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.695      0.705      0.724      0.584      0.695      0.705      0.714      0.702
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      78/200      6.12G     0.9113     0.2721    0.09517      0.445   0.002196     0.2365          3        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.2s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.873      0.658       0.75       0.57      0.873      0.658       0.75       0.74
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      79/200      6.12G      1.008     0.2296    0.09486     0.4926   0.002669     0.2222         11        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.665      0.665      0.711      0.542      0.665      0.665      0.711      0.696
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      80/200      6.12G     0.9286     0.2316     0.1017     0.5191   0.002982     0.6225          4        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69        0.8      0.722      0.714      0.573      0.771      0.701      0.669      0.659
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      81/200      6.12G     0.9002     0.2585    0.07272     0.4118   0.002082    0.09926         10        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.722      0.701      0.742      0.589      0.703       0.68      0.721        0.7
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      82/200      6.12G     0.8383     0.2146    0.08269     0.3891    0.00207    0.02131         11        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.9s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.768      0.727      0.735      0.585       0.86      0.648      0.716        0.7
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      83/200      6.12G     0.8803     0.2526     0.0918     0.4398   0.002277     0.1789          7        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.735       0.65      0.703      0.577      0.735       0.65      0.703      0.691
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      84/200      6.12G     0.8939     0.2405    0.09728     0.4424   0.002722      0.504          3        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 22.0s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69      0.623      0.687      0.658      0.516      0.623      0.687      0.658       0.64
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      85/200      6.12G     0.9184     0.2474    0.07861     0.4578   0.002444     0.1495          5        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.7s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.6s
#                    all         21         69      0.837      0.639      0.754       0.61      0.837      0.639      0.754      0.741
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      86/200      6.12G     0.8557     0.2624    0.07325     0.4271   0.002032     0.1483         11        640: 100% ━━━━━━━━━━━━ 43/43 1.9it/s 22.1s0.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.6s
#                    all         21         69      0.848      0.681      0.743      0.605      0.848      0.678      0.714      0.706
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#      87/200      6.12G     0.8566     0.2647    0.09242     0.4638   0.002187      0.251          3        640: 100% ━━━━━━━━━━━━ 43/43 2.0it/s 21.8s0.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         21         69      0.898      0.688      0.782      0.614      0.898      0.688      0.769      0.753
# EarlyStopping: Training stopped early as no improvement observed in last 50 epochs. Best results observed at epoch 37, best model saved as best.pt.
# To update EarlyStopping(patience=50) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 87 epochs completed in 0.580 hours.
# Optimizer stripped from /kaggle/working/runs/pose_model/weights/last.pt, 47.6MB
# Optimizer stripped from /kaggle/working/runs/pose_model/weights/best.pt, 47.6MB
#
# Validating /kaggle/working/runs/pose_model/weights/best.pt...
# YOLO26m-pose summary (fused): 142 layers, 21,203,132 parameters, 0 gradients, 71.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         21         69       0.78      0.834      0.862      0.641       0.78      0.834      0.862      0.819
#               anten-4G         21         48      0.769      0.875      0.887      0.684      0.769      0.875      0.887      0.881
#               anten-5G          5          7      0.651      0.803      0.785      0.568      0.651      0.803      0.785      0.689
#                    rrh          2          2          1      0.907      0.995      0.795          1      0.907      0.995      0.945
#                    rru          7         12      0.701       0.75       0.78      0.517      0.701       0.75       0.78      0.759
# Speed: 0.2ms preprocess, 10.8ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /kaggle/working/runs/pose_model
# [OK] Train xong.

# %%
# 5. ĐÁNH GIÁ TRÊN TEST SPLIT + NÉN KẾT QUẢ
best = '/kaggle/working/runs/pose_model/weights/best.pt'
m = YOLO(best)

try:
    r = m.val(data=working_yaml, split='test', imgsz=img_size, device=device.split(',')[0], plots=False)
    print(f'\n=== TEST ({model_variant}) ===')
    print(f'  Box  mAP50={r.box.map50:.4f}  mAP50-95={r.box.map:.4f}')
    print(f'  Pose mAP50={r.pose.map50:.4f}  mAP50-95={r.pose.map:.4f}')
except Exception as e:
    print('Bo qua val test:', e)

zip_path = shutil.make_archive('/kaggle/working/training_results_yolo26m', 'zip', '/kaggle/working/runs')
print(f'\n[OK] Da nen: {zip_path}  ({os.path.getsize(zip_path)/1024/1024:.1f} MB)')
print('=> Tai file training_results_yolo26m.zip ve may.')

for _v in ('model', 'm'):          # don RAM; dung globals() de khong loi neu cell 4 chua chay
    globals().pop(_v, None)
gc.collect()
# Out:
# Ultralytics 8.4.107 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26m-pose summary (fused): 142 layers, 21,203,132 parameters, 0 gradients, 71.6 GFLOPs
# WARNING ⚠️ val: Slow image access detected (ping: 1.3±0.2 ms, read: 40.9±35.3 MB/s, size: 161.5 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/input/datasets/tungtungtungtung/data-pose-final/test/labels... 21 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 21/21 217.9it/s 0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/tungtungtungtung/data-pose-final/test is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.4it/s 0.8s2.3s
#                    all         21         56      0.473      0.977      0.755      0.579      0.459      0.935      0.725       0.72
#               anten-4G         21         43      0.632      0.907      0.886      0.653      0.632      0.907      0.874      0.861
#               anten-5G          6          6      0.297          1       0.64      0.489      0.247      0.833      0.534      0.527
#                    rrh          1          1      0.461          1      0.497      0.348       0.46          1      0.497      0.497
#                    rru          5          6        0.5          1      0.995      0.828        0.5          1      0.995      0.995
# Speed: 0.8ms preprocess, 26.2ms inference, 0.0ms loss, 0.2ms postprocess per image
#
# === TEST (yolo26m-pose.pt) ===
#   Box  mAP50=0.7546  mAP50-95=0.5793
#   Pose mAP50=0.7252  mAP50-95=0.7201
#
# [OK] Da nen: /kaggle/working/training_results_yolo26m.zip  (87.2 MB)
# => Tai file training_results_yolo26m.zip ve may.
# 18650
